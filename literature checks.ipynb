# %%
import pandas as pd

df = pd.read_csv('/Users/ds39/Downloads/SSE_Formulations.csv')

# %%
# Select the second row (index 1) and remove columns where the value is NaN or '-'
cleaned_row = df.iloc[195].replace('-', pd.NA).dropna()

# Convert back to a DataFrame
df_cleaned = cleaned_row.to_frame().T
df_cleaned
# Out:
#                                            Article             Author  \
# 195  https://doi.org/10.1016/j.jconrel.2019.04.021  Croitoru-Sadger-3
#
#      Formulation_id Operator      Source  \
# 195  Prednisone_3:1   Gloria  literature
#
#     3D printing technology (SSE - Semi Solid Extrusion; SSE-MF - Semi Solid Extrusion - Mould filling; SSE-CF - Semi Solid Extrusion - Capsule filling)  \
# 195                                                SSE
#
#     Polyethylene_glycol_(PEG4-PCL-NH2)@Croitoru-Sadger  \
# 195                                             0.2483
#
#     Polyethylene_glycol_(PEG4-PCL-SC)@Croitoru-Sadger  \
# 195                                            0.7447
#
#     Prednisone@Tzamal_D-Chem_Laboratories Total  \
# 195                                 0.007   1.0
#
#     Type of Formulation (patches, capsules,  orodispersible films, tablets, troche, chewable printlets, controlled release, immediate release, polypills, emulsifying, capsule_(capsule filling)  \
# ...

# %%
dict(df_cleaned)
# Out:
# {'Article': 195    https://doi.org/10.1016/j.jconrel.2019.04.021
#  Name: Article, dtype: object,
#  'Author': 195    Croitoru-Sadger-3
#  Name: Author, dtype: object,
#  'Formulation_id': 195    Prednisone_3:1
#  Name: Formulation_id, dtype: object,
#  'Operator': 195    Gloria
#  Name: Operator, dtype: object,
#  'Source': 195    literature
#  Name: Source, dtype: object,
#  '3D printing technology (SSE - Semi Solid Extrusion; SSE-MF - Semi Solid Extrusion - Mould filling; SSE-CF - Semi Solid Extrusion - Capsule filling)': 195    SSE
#  Name: 3D printing technology (SSE - Semi Solid Extrusion; SSE-MF - Semi Solid Extrusion - Mould filling; SSE-CF - Semi Solid Extrusion - Capsule filling), dtype: object,
#  'Polyethylene_glycol_(PEG4-PCL-NH2)@Croitoru-Sadger': 195    0.2483
#  Name: Polyethylene_glycol_(PEG4-PCL-NH2)@Croitoru-Sadger, dtype: object,
#  'Polyethylene_glycol_(PEG4-PCL-SC)@Croitoru-Sadger': 195    0.7447
# ...
